# %%
#Q1
x=10
y=20
print(x+y)
# Out:
# 30

# %%
#Q2
a="Mahima"
print("Hello",a)
# Out:
# Hello Mahima

# %%
#Q3
a=5
b=10
a,b=b,a
print("a =",a)
print("b =",b)
# Out:
# a = 10
# b = 5

# %%
#Q4
a=int(input("enter your age"))
print("you are",a,"years old")
# Out:
# you are 10 years old

# %%
#Q5
a=int(input("enter a number"))
if a%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
#Q6
a=15
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 19
# 11
# 60
# 3.75
# 3

# %%
#Q7
a=4
if a>0:
    print("positive")
elif a<0:
    print("negative")
else:
    print("zero")
# Out:
# positive
