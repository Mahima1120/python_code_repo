# %%
r=int(input("enter no of rows:"))
s=input("enter symbol")

i=1
while i<=r:
    j=1
    while j<=i:
        print(s,end='')
        j+=1
    print()
    i+=1
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$

# %%
for x in range(5):
    for y in range(1,6):
        print('*',end='')
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
x=1
while x<=5:
    y=1
    while y<=5:
        print("*",end='')
        y+=1
    x+=1
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
x=int(input("enter row number"))
s=input("enter symbol")

for i in range(x):
    for j in range(0,i+1):
        print(s,end='')
    print()
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$
