# %%
r=int(input("enter no of rows:"))
s=input("enter symbol")

i=1
while i<=r:
    j=1
    while j<=i:
        print(s,end='')
        j+=1
    print()
    i+=1
# Out:
# *
# **
# ***
# ****
# *****

# %%
r=5

i=1
while i<=r:
    j=1
    while j<=i:
        print('*',end='')
        j+=1
    print()
    i+=1
# Out:
# *
# **
# ***
# ****
# *****
